# %%
1+1
mean (runif(100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 1+1
# ----> 2 mean (runif(100))
#
# NameError: name 'mean' is not defined

# %%
1:10
2**10
abs(rnorm(10))
